# %% [markdown]
# # Attack on scAnnotatR on axilla 10k cells dataset
#
# - How to train a scAnnotatR classifier
# - How to format the classifier to use it with adverSCarial
# - How to run an IGD4C attack
#
# Nguyen, V., Griss, J. scAnnotatR: framework to accurately classify cell types in single-cell RNA-sequencing data. BMC Bioinformatics, 2022. 23(44) https://doi.org/10.1186/s12859-022-04574-5

# %%
library(scAnnotatR)
library(IRdisplay)
library(adverSCarial)
# Out:
# Loading required package: Seurat
#
# Loading required package: SeuratObject
#
# Loading required package: sp
#
# The legacy packages maptools, rgdal, and rgeos, underpinning the sp package,
# which was just loaded, will retire in October 2023.
# Please refer to R-spatial evolution reports for details, especially
# https://r-spatial.org/r/2023/05/15/evolution4.html.
# It may be desirable to make the sf package available;
# package maintainers should consider adding sf to Suggests:.
# The sp package is now running under evolution status 2
#      (status 2 uses the sf package in place of rgdal)
#
#
# Attaching package: ‘SeuratObject’
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, t
#
#
# Loading required package: SingleCellExperiment
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: GenomicRanges
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following object is masked from ‘package:SeuratObject’:
#
#     intersect
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
#
# Attaching package: ‘IRanges’
#
#
# The following object is masked from ‘package:sp’:
#
#     %over%
#
#
# Loading required package: GenomeInfoDb
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘SummarizedExperiment’
#
#
# The following object is masked from ‘package:Seurat’:
#
#     Assays
#
#
# The following object is masked from ‘package:SeuratObject’:
#
#     Assays
#
#
# Warning message:
# “replacing previous import ‘ape::where’ by ‘dplyr::where’ when loading ‘scAnnotatR’”

# %% [markdown]
# # scAnnotatR classifier training
#
# Load previously splitted train/test pbmc3k dataset
# https://cf.10xgenomics.com/samples/cell/pbmc3k/pbmc3k_filtered_gene_bc_matrices.tar.gz
#
# annotated from the Seurat tutorial method
# https://satijalab.org/seurat/articles/pbmc3k_tutorial

# %%
c_basen = c("hgnc_axilla_10k", "hgnc_brain_7k", "hgnc_liver_6k")
basen = c_basen[1]

# %%
se_train <- readRDS(paste0("data//v5/data//sc//",basen,"_train.rds"))
se_test <- readRDS(paste0("data//v5/data//sc//",basen,"_test.rds"))

# %%
unique(se_train@meta.data[['chr_seurat_cluster']])
# Out:
# [1] malignant cell                  blood vessel endothelial cell
# [3] fibroblast                      macrophage
# [5] blood vessel smooth muscle cell T cell
# 6 Levels: malignant cell < blood vessel endothelial cell < ... < T cell

# %%
Idents(se_train) <- "chr_seurat_cluster"
Idents(se_test) <- "chr_seurat_cluster"

# %%
head(se_train@meta.data)
# Out:
#                                                    orig.ident
# HTAPP-878-SMP-7149-TST-channel1_CGTTCTGCAGTCGCTG-1 HTAPP-878-SMP-7149-TST-channel1
# HTAPP-878-SMP-7149-TST-channel1_GCACGGTTCGATACTG-1 HTAPP-878-SMP-7149-TST-channel1
# HTAPP-878-SMP-7149-TST-channel1_TGTCCACAGTCATAGA-1 HTAPP-878-SMP-7149-TST-channel1
# HTAPP-878-SMP-7149-TST-channel1_TTTAGTCTCCACGTCT-1 HTAPP-878-SMP-7149-TST-channel1
# HTAPP-878-SMP-7149-TST-channel1_CCCGGAACAAGTGGAC-1 HTAPP-878-SMP-7149-TST-channel1
# HTAPP-878-SMP-7149-TST-channel1_GAGACTTTCATTTCCA-1 HTAPP-878-SMP-7149-TST-channel1
#                                                    nCount_RNA nFeature_RNA
# HTAPP-878-SMP-7149-TST-channel1_CGTTCTGCAGTCGCTG-1 19735      6278
# HTAPP-878-SMP-7149-TST-channel1_GCACGGTTCGATACTG-1 19848      7140
# HTAPP-878-SMP-7149-TST-channel1_TGTCCACAGTCATAGA-1 19288      5699
# HTAPP-878-SMP-7149-TST-channel1_TTTAGTCTCCACGTCT-1 19569      6949
# HTAPP-878-SMP-7149-TST-channel1_CCCGGAACAAGTGGAC-1 19440      6553
# HTAPP-878-SMP-7149-TST-channel1_GAGACTTTCATTTCCA-1 19421      7104
#                                                    replicate condition
# HTAPP-878-SMP-7149-TST-channel1_CGTTCTGCAGTCGCTG-1 1         TST
# HTAPP-878-SMP-7149-TST-channel1_GCACGGTTCGATACTG-1 1         TST
# HTAPP-878-SMP-7149-TST-channel1_TGTCCACAGTCATAGA-1 1         TST
# HTAPP-878-SMP-7149-TST-channel1_TTTAGTCTCCACGTCT-1 1         TST
# HTAPP-878-SMP-7149-TST-channel1_CCCGGAACAAGTGGAC-1 1         TST
# HTAPP-878-SMP-7149-TST-channel1_GAGACTTTCATTTCCA-1 1         TST
#                                                    labels_unif labels_cl_unif
# HTAPP-878-SMP-7149-TST-channel1_CGTTCTGCAGTCGCTG-1 Epithelial  Epithelial
# HTAPP-878-SMP-7149-TST-channel1_GCACGGTTCGATACTG-1 Epithelial  Epithelial
# HTAPP-878-SMP-7149-TST-channel1_TGTCCACAGTCATAGA-1 Epithelial  Epithelial
# HTAPP-878-SMP-7149-TST-channel1_TTTAGTCTCCACGTCT-1 Epithelial  Epithelial
# HTAPP-878-SMP-7149-TST-channel1_CCCGGAACAAGTGGAC-1 Epithelial  Epithelial
# HTAPP-878-SMP-7149-TST-channel1_GAGACTTTCATTTCCA-1 Epithelial  Epithelial
#                                                    labels_cl_unif2_broad
# HTAPP-878-SMP-7149-TST-channel1_CGTTCTGCAGTCGCTG-1 Epithelial
# HTAPP-878-SMP-7149-TST-channel1_GCACGGTTCGATACTG-1 Epithelial
# HTAPP-878-SMP-7149-TST-channel1_TGTCCACAGTCATAGA-1 Epithelial
# HTAPP-878-SMP-7149-TST-channel1_TTTAGTCTCCACGTCT-1 Epithelial
# HTAPP-878-SMP-7149-TST-channel1_CCCGGAACAAGTGGAC-1 Epithelial
# HTAPP-878-SMP-7149-TST-channel1_GAGACTTTCATTTCCA-1 Epithelial
#                                                    compartments cnv_pass_mal ⋯
# HTAPP-878-SMP-7149-TST-channel1_CGTTCTGCAGTCGCTG-1 Malignant    True         ⋯
# HTAPP-878-SMP-7149-TST-channel1_GCACGGTTCGATACTG-1 Malignant    True         ⋯
# HTAPP-878-SMP-7149-TST-channel1_TGTCCACAGTCATAGA-1 Malignant    True         ⋯
# HTAPP-878-SMP-7149-TST-channel1_TTTAGTCTCCACGTCT-1 Malignant    True         ⋯
# HTAPP-878-SMP-7149-TST-channel1_CCCGGAACAAGTGGAC-1 Malignant    True         ⋯
# HTAPP-878-SMP-7149-TST-channel1_GAGACTTTCATTTCCA-1 Malignant    True         ⋯
#                                                    cell_type      assay
# HTAPP-878-SMP-7149-TST-channel1_CGTTCTGCAGTCGCTG-1 malignant cell 10x 3' v3
# HTAPP-878-SMP-7149-TST-channel1_GCACGGTTCGATACTG-1 malignant cell 10x 3' v3
# HTAPP-878-SMP-7149-TST-channel1_TGTCCACAGTCATAGA-1 malignant cell 10x 3' v3
# HTAPP-878-SMP-7149-TST-channel1_TTTAGTCTCCACGTCT-1 malignant cell 10x 3' v3
# HTAPP-878-SMP-7149-TST-channel1_CCCGGAACAAGTGGAC-1 malignant cell 10x 3' v3
# HTAPP-878-SMP-7149-TST-channel1_GAGACTTTCATTTCCA-1 malignant cell 10x 3' v3
#                                                    disease       organism
# HTAPP-878-SMP-7149-TST-channel1_CGTTCTGCAGTCGCTG-1 breast cancer Homo sapiens
# HTAPP-878-SMP-7149-TST-channel1_GCACGGTTCGATACTG-1 breast cancer Homo sapiens
# HTAPP-878-SMP-7149-TST-channel1_TGTCCACAGTCATAGA-1 breast cancer Homo sapiens
# HTAPP-878-SMP-7149-TST-channel1_TTTAGTCTCCACGTCT-1 breast cancer Homo sapiens
# HTAPP-878-SMP-7149-TST-channel1_CCCGGAACAAGTGGAC-1 breast cancer Homo sapiens
# HTAPP-878-SMP-7149-TST-channel1_GAGACTTTCATTTCCA-1 breast cancer Homo sapiens
#                                                    sex    tissue
# HTAPP-878-SMP-7149-TST-channel1_CGTTCTGCAGTCGCTG-1 female axilla
# HTAPP-878-SMP-7149-TST-channel1_GCACGGTTCGATACTG-1 female axilla
# HTAPP-878-SMP-7149-TST-channel1_TGTCCACAGTCATAGA-1 female axilla
# HTAPP-878-SMP-7149-TST-channel1_TTTAGTCTCCACGTCT-1 female axilla
# HTAPP-878-SMP-7149-TST-channel1_CCCGGAACAAGTGGAC-1 female axilla
# HTAPP-878-SMP-7149-TST-channel1_GAGACTTTCATTTCCA-1 female axilla
#                                                    self_reported_ethnicity
# HTAPP-878-SMP-7149-TST-channel1_CGTTCTGCAGTCGCTG-1 European
# HTAPP-878-SMP-7149-TST-channel1_GCACGGTTCGATACTG-1 European
# HTAPP-878-SMP-7149-TST-channel1_TGTCCACAGTCATAGA-1 European
# HTAPP-878-SMP-7149-TST-channel1_TTTAGTCTCCACGTCT-1 European
# HTAPP-878-SMP-7149-TST-channel1_CCCGGAACAAGTGGAC-1 European
# HTAPP-878-SMP-7149-TST-channel1_GAGACTTTCATTTCCA-1 European
#                                                    development_stage
# HTAPP-878-SMP-7149-TST-channel1_CGTTCTGCAGTCGCTG-1 37-year-old human stage
# HTAPP-878-SMP-7149-TST-channel1_GCACGGTTCGATACTG-1 37-year-old human stage
# HTAPP-878-SMP-7149-TST-channel1_TGTCCACAGTCATAGA-1 37-year-old human stage
# HTAPP-878-SMP-7149-TST-channel1_TTTAGTCTCCACGTCT-1 37-year-old human stage
# HTAPP-878-SMP-7149-TST-channel1_CCCGGAACAAGTGGAC-1 37-year-old human stage
# HTAPP-878-SMP-7149-TST-channel1_GAGACTTTCATTTCCA-1 37-year-old human stage
#                                                    observation_joinid
# HTAPP-878-SMP-7149-TST-channel1_CGTTCTGCAGTCGCTG-1 KYeaGobvIQ
# HTAPP-878-SMP-7149-TST-channel1_GCACGGTTCGATACTG-1 @dk<quR-I{
# HTAPP-878-SMP-7149-TST-channel1_TGTCCACAGTCATAGA-1 g%ROJ`3nnu
# HTAPP-878-SMP-7149-TST-channel1_TTTAGTCTCCACGTCT-1 (HRUf-FqnM
# HTAPP-878-SMP-7149-TST-channel1_CCCGGAACAAGTGGAC-1 X_LhOX=$9;
# HTAPP-878-SMP-7149-TST-channel1_GAGACTTTCATTTCCA-1 r0fjWR$I_}
#                                                    chr_seurat_cluster
# HTAPP-878-SMP-7149-TST-channel1_CGTTCTGCAGTCGCTG-1 malignant cell
# HTAPP-878-SMP-7149-TST-channel1_GCACGGTTCGATACTG-1 malignant cell
# HTAPP-878-SMP-7149-TST-channel1_TGTCCACAGTCATAGA-1 malignant cell
# HTAPP-878-SMP-7149-TST-channel1_TTTAGTCTCCACGTCT-1 malignant cell
# HTAPP-878-SMP-7149-TST-channel1_CCCGGAACAAGTGGAC-1 malignant cell
# HTAPP-878-SMP-7149-TST-channel1_GAGACTTTCATTTCCA-1 malignant cell

# %% [markdown]
# ## Function to get the most significant genes between a cluster and the other cells

# %%
getSignGenesNot <- function(expr, clusters, target, method="wilcox", adjMethod="BH", verbose=FALSE){
        if (verbose) {message("Cluster ",target," vs all the other clusters")}
        pvals <- apply(t(expr), 1, function(x){
            c1 <- x[clusters == target]
            c1 <- c1[!is.na(c1)]
            c2 <- x[clusters != target]
            c2 <- c2[!is.na(c2)]
            if ( length(c1) == 0 || length(c2) == 0){
                return(1)
            }
            if (length(unique(c1))==1){
                c1[1] = c1[1] + 0.00001
            }
            if (length(unique(c2))==1){
                c2[1] = c2[1] + 0.00001
            }
            if (method=="wilcox"){
                return(wilcox.test(c1, c2)$p.value)
            }
            if (method=="ttest"){
                return(t.test(c1, c2)$p.value)
            }
        })
        means <- apply(t(expr), 1, function(x){
                c1 <- x[clusters == target]
                c1 <- c1[!is.na(c1)]
                c2 <- x[clusters != target]
                c2 <- c2[!is.na(c2)]
                if (length(c1) == 0){
                    c1 = c(0)
                }
                if (length(c2) == 0){
                    c2 = c(0)
                }
                return(mean(c1)-mean(c2))
        })  
        dfPvals <- data.frame(gene=colnames(expr), pval=unname(pvals), mean=means)
        rownames(dfPvals) <- dfPvals$gene

        for (clustInt in setdiff(unique(clusters), target)){
            if(verbose){message("Cluster ", target, " vs cluster ", clustInt)}
            newPvals <- pvals <- apply(t(expr), 1, function(x){
                c1 <- x[clusters == target]
                c1 <- c1[!is.na(c1)]
                c2 <- x[clusters == clustInt]
                c2 <- c2[!is.na(c2)]
                if ( length(c1) == 0 || length(c2) == 0){
                    return(1)
                }
                if (length(unique(c1))==1){
                    c1[1] = c1[1] + 0.001
                }
                if (length(unique(c2))==1){
                    c2[1] = c2[1] + 0.001
                }
                if (method=="wilcox"){
                    return(wilcox.test(c1, c2)$p.value)
                }
                if (method=="ttest"){
                    return(t.test(c1, c2)$p.value)
                }    
            })
            newMeans <- pvals <- apply(t(expr), 1, function(x){
                c1 <- x[clusters == target]
                c1 <- c1[!is.na(c1)]
                c2 <- x[clusters == clustInt]
                c2 <- c2[!is.na(c2)]
                if (length(c1) == 0){
                    c1 = c(0)
                }
                if (length(c2) == 0){
                    c2 = c(0)
                }
                return(mean(c1)-mean(c2))
            })  
            if(verbose){message(sum(unname(newPvals) < dfPvals$pval)," pvalues replaced by lower values")}
            dfPvals[unname(newPvals) < dfPvals$pval, "pval"] <- newPvals[unname(newPvals) < dfPvals$pval]
            dfPvals[unname(newPvals) < dfPvals$pval, "mean"] <- newMeans[unname(newPvals) < dfPvals$pval]
    }
    dfPvals$adjPval <- p.adjust(dfPvals$pval, method=adjMethod)
    dfPvals <- dfPvals[order(dfPvals$pval),]
    return(dfPvals)
}

# %%
dfScaled <- as.data.frame(se_train@assays$RNA@layers$scale.data)
colnames(dfScaled) <- rownames(se_train@assays$RNA@cells)
rownames(dfScaled) <- rownames(se_train@assays$RNA@features)
dfScaled <- as.data.frame(t(dfScaled))

# %% [markdown]
# The scAnnotatR will build one classifier to predict each cell type, so we one-hot encode the cell type by adding a meta.data column for each cell type with binary information: cell type or "unknown".

# %%
for (cellType in unique(se_train@meta.data$chr_seurat_cluster)){
    se_train@meta.data[[cellType]] <- unlist(lapply(se_train@meta.data$chr_seurat_cluster, function(x){
        if (x == cellType){
            return(cellType)
        } else {
            return("unknown")
        }
    }))
}

# %% [markdown]
# ## Train and export one classifier for each cell type

# %%
listClassifiers <- list()
for (cellType in unique(se_train@meta.data$chr_seurat_cluster)){
    display(cellType)
    sg <- getSignGenesNot(dfScaled,
                   se_train@meta.data$chr_seurat_cluster,
                   cellType)
    # Selection of the 20 most significants with a minimum mean difference of 0.5 for the SVM
    selectedMarkers <- rownames(sg[abs(sg$mean)>0.5,])[1:20]
    classifier <- train_classifier(train_obj = se_train, cell_type = cellType, 
                                 marker_genes = selectedMarkers,
                                 assay = 'RNA', tag_slot = cellType)
    listClassifiers[[cellType]] <- classifier
    
    save_new_model(new_model = classifier,
                   path_to_models = paste0("repr_data/classifiers/scAnnotatR/trainedClass_", basen),
               include.default = FALSE) 
}
listClassifiers[[cellType]]
# Out:
# [1] "malignant cell"

# %% [markdown]
# # Format the Classifier
# To work with adverSCarial the classifier needs to be formated in a certain way.

# %%
scAnnotatR_classifier = function(expr, clusters, target){
    if (!"scAnnotatR" %in% loadedNamespaces()){
        library(scAnnotatR)
    }
    if ( !exists("sca_default_models")){
        sca_default_models <<- load_models(paste0("repr_data/classifiers/scAnnotatR/trainedClass_", basen))
        sca_cell_types <<- names(sca_default_models)
    }
    
    seurat.obj <- classify_cells(classify_obj = expr, 
                             assay = 'RNA', slot = 'scale.data',
                             cell_types = sca_cell_types, 
                             path_to_models = paste0("repr_data/classifiers/scAnnotatR/trainedClass_", basen))
    typePredictions <- seurat.obj@meta.data[, stringr::str_replace_all( paste0(sca_cell_types, "_p"), " ", "_")]
    
    pred_table <- table(seurat.obj@meta.data[clusters == target, "most_probable_cell_type"])
    cluster_pred <- names(pred_table[order(pred_table, decreasing = TRUE)])[1]
    odd <- unname(pred_table[cluster_pred]/sum(pred_table))
    colnames(typePredictions) <- unlist(lapply(colnames(typePredictions), function(x){
        unlist(strsplit(x,"_p$"))[1]
    }))
    typePredictions <- as.data.frame(t(typePredictions))
    
    result <- list(
        # Cell type prediction for the cluster
        prediction=stringr::str_replace_all(cluster_pred," ","_"),
        # Score of the predicted cell type
        odd=odd, 
        # Score for each cell type for each cell
        typePredictions=typePredictions,
        # Cell type for each cell
        cellTypes=seurat.obj@meta.data$most_probable_cell_type)
    return(result)
}

# %% [markdown]
# # Adversarial attack of the malignant cell cells cluster

# %%
so_pbmc_test <- se_test
clusters_so = so_pbmc_test@meta.data$chr_seurat_cluster
names(clusters_so) <- rownames(so_pbmc_test@meta.data)

# %% [markdown]
# cell types clusters

# %%
unique(clusters_so)
# Out:
# [1] malignant cell                  blood vessel endothelial cell
# [3] fibroblast                      macrophage
# [5] blood vessel smooth muscle cell T cell
# 6 Levels: malignant cell < blood vessel endothelial cell < ... < T cell

# %% [markdown]
# We check if the classifier is working properly, it predicts the NK cells cluster as NK cells

# %%
class_results <- scAnnotatR_classifier(so_pbmc_test, clusters_so, 'macrophage')

# %%
class_results$prediction
# Out:
# [1] "macrophage"

# %%
dfScaled <- as.data.frame(so_pbmc_test@assays$RNA@layers$scale.data)
colnames(dfScaled) <- rownames(so_pbmc_test@assays$RNA@cells)
rownames(dfScaled) <- rownames(so_pbmc_test@assays$RNA@features)
dfScaled <- t(dfScaled)

# %%
dfScaled[1:5,1:5]
# Out:
#                                                    ENSG00000238009
# HTAPP-878-SMP-7149-TST-channel1_GATGTTGCAAACGTGG-1 -0.2027578
# HTAPP-878-SMP-7149-TST-channel1_CTTTCAAGTAGGTACG-1 -0.2027578
# HTAPP-878-SMP-7149-TST-channel1_CACCGTTGTTCTGACA-1 -0.2027578
# HTAPP-878-SMP-7149-TST-channel1_GAGTTTGCACAACGTT-1  1.5589332
# HTAPP-878-SMP-7149-TST-channel1_GATGACTTCTTTGCTA-1 -0.2027578
#                                                    ENSG00000241599
# HTAPP-878-SMP-7149-TST-channel1_GATGTTGCAAACGTGG-1 -0.01920534
# HTAPP-878-SMP-7149-TST-channel1_CTTTCAAGTAGGTACG-1 -0.01920534
# HTAPP-878-SMP-7149-TST-channel1_CACCGTTGTTCTGACA-1 -0.01920534
# HTAPP-878-SMP-7149-TST-channel1_GAGTTTGCACAACGTT-1 -0.01920534
# HTAPP-878-SMP-7149-TST-channel1_GATGACTTCTTTGCTA-1 -0.01920534
#                                                    ENSG00000235146 LINC01409
# HTAPP-878-SMP-7149-TST-channel1_GATGTTGCAAACGTGG-1 -0.04245598     0.7910192
# HTAPP-878-SMP-7149-TST-channel1_CTTTCAAGTAGGTACG-1 -0.04245598     0.2370915
# HTAPP-878-SMP-7149-TST-channel1_CACCGTTGTTCTGACA-1 -0.04245598     0.7840407
# HTAPP-878-SMP-7149-TST-channel1_GAGTTTGCACAACGTT-1 -0.04245598     0.8048589
# HTAPP-878-SMP-7149-TST-channel1_GATGACTTCTTTGCTA-1 -0.04245598     0.2525219
#                                                    FAM87B
# HTAPP-878-SMP-7149-TST-channel1_GATGTTGCAAACGTGG-1 -0.01895955
# HTAPP-878-SMP-7149-TST-channel1_CTTTCAAGTAGGTACG-1 -0.01895955
# HTAPP-878-SMP-7149-TST-channel1_CACCGTTGTTCTGACA-1 -0.01895955
# HTAPP-878-SMP-7149-TST-channel1_GAGTTTGCACAACGTT-1 -0.01895955
# HTAPP-878-SMP-7149-TST-channel1_GATGACTTCTTTGCTA-1 -0.01895955

# %% [markdown]
# We use the adverSCarial getSignGenes function to get the most significant genes between clusters, ensuring that all pairs of clusters are equivalently representated.

# %%
start_time <- Sys.time()

# %%
sign_genes <- getSignGenes(dfScaled, clusters_so)

# %%
Sys.time() - start_time
# Out:
# Time difference of 17.79068 mins

# %%
head(sign_genes$results)
# Out:
#          gene     pval
# HSPG2    HSPG2     0.000000e+00
# MSR1     MSR1     6.526758e-284
# PRKG1    PRKG1    3.456779e-180
# CASZ1    CASZ1     0.000000e+00
# ARHGAP15 ARHGAP15 2.876970e-183
# MCAM     MCAM     1.122424e-226

# %% [markdown]
# We launch the attack with the advCGD function with alpha=2 and epsilon=2 parameters, which lead to a big modification on a few genes. You can try with alpha=1 and epsilon=1 to have small modifications of more genes.

# %%
start_time <- Sys.time()

# %%
igd4c_results <- advCGD(so_pbmc_test, clusters_so, 'macrophage',
                          scAnnotatR_classifier, alpha=2,
                          epsilon=2, slot="scale.data",
                          genes=sign_genes$results$gene[1:500],
                         verbose=T)
# Out:
# macrophage
#
# 53126
#
# 5312
#
# 392
#
# New cluster target: T_cell
#
# HSPG2 1
#
# Number of original annot macrophage : 370
#
#  mean 0.959160038401541 delt 0
#
# Number of T_cell : 14
#
#  mean 0.737670271885174 delt 0
#
# Number of modified cells 0
#
# MSR1 2
#
# Number of original annot macrophage : 370
#
#  mean 0.959160038401541 delt 0
#
# Number of T_cell : 14
#
#  mean 0.737670271885174 delt 0
#
# Number of modified cells 378
#
# PRKG1 3
#
# Number of original annot macrophage : 361
#
#  mean 0.936429968420805 delt -0.022730069980736
#
# Number of T_cell : 16
#
#  mean 0.762200657720953 delt 0.0245303858357792
#
# Number of modified cells 0
#
# CASZ1 4
#
# Number of original annot macrophage : 361
#
#  mean 0.936429968420805 delt 0
#
# Number of T_cell : 16
#
#  mean 0.762200657720953 delt 0
#
# Number of modified cells 0
#
# ARHGAP15 5
#
# Number of original annot macrophage : 361
#
#  mean 0.936429968420805 delt 0
#
# Number of T_cell : 16
#
#  mean 0.762200657720953 delt 0
#
# Number of modified cells 376
#
# MCAM 6
#
# Number of original annot macrophage : 361
#
#  mean 0.936057724252099 delt -0.000372244168706404
#
# Number of T_cell : 16
#
#  mean 0.767308161684758 delt 0.00510750396380466
#
# Number of modified cells 0
#
# LRMDA 7
#
# Number of original annot macrophage : 361
#
#  mean 0.936057724252099 delt 0
#
# Number of T_cell : 16
#
#  mean 0.767308161684758 delt 0
#
# Number of modified cells 0
#
# ZEB2 8
#
# Number of original annot macrophage : 361
#
#  mean 0.936057724252099 delt 0
#
# Number of T_cell : 16
#
#  mean 0.767308161684758 delt 0
#
# Number of modified cells 376
#
# TIE1 9
#
# Number of original annot macrophage : 289
#
#  mean 0.867339598418616 delt -0.0687181258334827
#
# Number of T_cell : 52
#
#  mean 0.54938150603057 delt -0.217926655654189
#
# Number of modified cells 0
#
# CALD1 10
#
# Number of original annot macrophage : 289
#
#  mean 0.867339598418616 delt 0
#
# Number of T_cell : 52
#
#  mean 0.54938150603057 delt 0
#
# Number of modified cells 0
#
# PTPRC 11
#
# Number of original annot macrophage : 289
#
#  mean 0.867339598418616 delt 0
#
# Number of T_cell : 52
#
#  mean 0.54938150603057 delt 0
#
# Number of modified cells 340
#
# CARMN 12
#
# Number of original annot macrophage : 273
#
#  mean 0.898516343171954 delt 0.0311767447533373
#
# Number of T_cell : 74
#
#  mean 0.496518938307286 delt -0.0528625677232833
#
# Number of modified cells 0
#
# FYB1 13
#
# Number of original annot macrophage : 273
#
#  mean 0.898516343171954 delt 0
#
# Number of T_cell : 74
#
#  mean 0.496518938307286 delt 0
#
# Number of modified cells 0
#
# NHSL3 14
#
# Number of original annot macrophage : 273
#
#  mean 0.898516343171954 delt 0
#
# Number of T_cell : 74
#
#  mean 0.496518938307286 delt 0
#
# Number of modified cells 0
#
# LDB2 15
#
# Number of original annot macrophage : 273
#
#  mean 0.898516343171954 delt 0
#
# Number of T_cell : 74
#
#  mean 0.496518938307286 delt 0
#
# Number of modified cells 0
#
# CDH6 16
#
# Number of original annot macrophage : 273
#
#  mean 0.898516343171954 delt 0
#
# Number of T_cell : 74
#
#  mean 0.496518938307286 delt 0
#
# Number of modified cells 0
#
# PLXDC2 17
#
# Number of original annot macrophage : 273
#
#  mean 0.898516343171954 delt 0
#
# Number of T_cell : 74
#
#  mean 0.496518938307286 delt 0
#
# Number of modified cells 0
#
# TEX41 18
#
# Number of original annot macrophage : 273
#
#  mean 0.898516343171954 delt 0
#
# Number of T_cell : 74
#
#  mean 0.496518938307286 delt 0
#
# Number of modified cells 0
#
# ST6GALNAC3 19
#
# Number of original annot macrophage : 273
#
#  mean 0.898516343171954 delt 0
#
# Number of T_cell : 74
#
#  mean 0.496518938307286 delt 0
#
# Number of modified cells 0
#
# CD96 20
#
# Number of original annot macrophage : 273
#
#  mean 0.898516343171954 delt 0
#
# Number of T_cell : 74
#
#  mean 0.496518938307286 delt 0
#
# Number of modified cells 318
#
# SKAP1 21
#
# Number of original annot macrophage : 263
#
#  mean 0.908513028428304 delt 0.00999668525635067
#
# Number of T_cell : 100
#
#  mean 0.492207172926131 delt -0.00431176538115502
#
# Number of modified cells 292
#
# CHST11 22
#
# Number of original annot macrophage : 259
#
#  mean 0.911505235828596 delt 0.00299220740029216
#
# Number of T_cell : 113
#
#  mean 0.488722735495377 delt -0.00348443743075405
#
# Number of modified cells 279
#
# CALCRL 23
#
# Number of original annot macrophage : 216
#
#  mean 0.965654773469977 delt 0.0541495376413802
#
# Number of T_cell : 162
#
#  mean 0.601266669889959 delt 0.112543934394581
#
# Number of modified cells 0
#
# CYP4Z1 24
#
# Number of original annot macrophage : 216
#
#  mean 0.965654773469977 delt 0
#
# Number of T_cell : 162
#
#  mean 0.601266669889959 delt 0
#
# Number of modified cells 0
#
# LHFPL6 25
#
# Number of original annot macrophage : 216
#
#  mean 0.965654773469977 delt 0
#
# Number of T_cell : 162
#
#  mean 0.601266669889959 delt 0
#
# Number of modified cells 0
#
# MACF1 26
#
# Number of original annot macrophage : 216
#
#  mean 0.965654773469977 delt 0
#
# Number of T_cell : 162
#
#  mean 0.601266669889959 delt 0
#
# Number of modified cells 0
#
# ADGRB3 27
#
# Number of original annot macrophage : 216
#
#  mean 0.965654773469977 delt 0
#
# Number of T_cell : 162
#
#  mean 0.601266669889959 delt 0
#
# Number of modified cells 0
#
# FMNL2 28
#
# Number of original annot macrophage : 216
#
#  mean 0.965654773469977 delt 0
#
# Number of T_cell : 162
#
#  mean 0.601266669889959 delt 0
#
# Number of modified cells 0
#
# IGFBP7 29
#
# Number of original annot macrophage : 216
#
#  mean 0.965654773469977 delt 0
#
# Number of T_cell : 162
#
#  mean 0.601266669889959 delt 0
#
# Number of modified cells 0
#
# ADGRL4 30
#
# Number of original annot macrophage : 216
#
#  mean 0.965654773469977 delt 0
#
# Number of T_cell : 162
#
#  mean 0.601266669889959 delt 0
#
# Number of modified cells 0
#
# RIPOR2 31
#
# Number of original annot macrophage : 216
#
#  mean 0.965654773469977 delt 0
#
# Number of T_cell : 162
#
#  mean 0.601266669889959 delt 0
#
# Number of modified cells 230
#
# SLIT3 32
#
# Number of original annot macrophage : 197
#
#  mean 0.977875943865762 delt 0.0122211703957856
#
# Number of T_cell : 182
#
#  mean 0.630105582082103 delt 0.0288389121921443
#
# Number of modified cells 0
#
# PTPRG 33
#
# Number of original annot macrophage : 197
#
#  mean 0.977875943865762 delt 0
#
# Number of T_cell : 182
#
#  mean 0.630105582082103 delt 0
#
# Number of modified cells 0
#
# SAMSN1 34
#
# Number of original annot macrophage : 197
#
#  mean 0.977875943865762 delt 0
#
# Number of T_cell : 182
#
#  mean 0.630105582082103 delt 0
#
# Number of modified cells 0
#
# PTPRF 35
#
# Number of original annot macrophage : 197
#
#  mean 0.977875943865762 delt 0
#
# Number of T_cell : 182
#
#  mean 0.630105582082103 delt 0
#
# Number of modified cells 0
#
# DOCK10 36
#
# Number of original annot macrophage : 197
#
#  mean 0.977875943865762 delt 0
#
# Number of T_cell : 182
#
#  mean 0.630105582082103 delt 0
#
# Number of modified cells 0
#
# VCAN 37
#
# Number of original annot macrophage : 197
#
#  mean 0.977875943865762 delt 0
#
# Number of T_cell : 182
#
#  mean 0.630105582082103 delt 0
#
# Number of modified cells 0
#
# NEAT1 38
#
# Number of original annot macrophage : 197
#
#  mean 0.977875943865762 delt 0
#
# Number of T_cell : 182
#
#  mean 0.630105582082103 delt 0
#
# Number of modified cells 0
#
# ITGA1 39
#
# Number of original annot macrophage : 197
#
#  mean 0.977875943865762 delt 0
#
# Number of T_cell : 182
#
#  mean 0.630105582082103 delt 0
#
# Number of modified cells 0
#
# ARHGAP29 40
#
# Number of original annot macrophage : 197
#
#  mean 0.977875943865762 delt 0
#
# Number of T_cell : 182
#
#  mean 0.630105582082103 delt 0
#
# Number of modified cells 0
#
# SOX5 41
#
# Number of original annot macrophage : 197
#
#  mean 0.977875943865762 delt 0
#
# Number of T_cell : 182
#
#  mean 0.630105582082103 delt 0
#
# Number of modified cells 0
#
# FYN 42
#
# Number of original annot macrophage : 197
#
#  mean 0.977875943865762 delt 0
#
# Number of T_cell : 182
#
#  mean 0.630105582082103 delt 0
#
# Number of modified cells 210

# %% [markdown]
# # Computation time

# %%
Sys.time() - start_time
# Out:
# Time difference of 21.19147 mins

# %% [markdown]
# We can see the genes that have been modified

# %%
igd4c_results$modGenes
# Out:
# [1] "MSR1"     "ARHGAP15" "ZEB2"     "PTPRC"    "CD96"     "SKAP1"    "CHST11"
# [8] "RIPOR2"   "FYN"

# %% [markdown]
# And the modified Seurat object

# %%
igd4c_results$expr
# Out:
# An object of class Seurat
# 25345 features across 5312 samples within 1 assay
# Active assay: RNA (25345 features, 0 variable features)
#  3 layers present: counts, data, scale.data

# %% [markdown]
# The malignant cell cluster is now classified as CD8 T cells

# %%
new_classification <- scAnnotatR_classifier(igd4c_results$expr, clusters_so, 'macrophage')
new_classification$prediction
# Out:
# [1] "T_cell"

# %%
sessionInfo()
# Out:
# R version 4.3.0 (2023-04-21)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 22.04.1 LTS
#
# Matrix products: default
# BLAS:   /usr/lib/x86_64-linux-gnu/blas/libblas.so.3.10.0
# LAPACK: /usr/lib/x86_64-linux-gnu/lapack/liblapack.so.3.10.0
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=fr_FR.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=fr_FR.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=fr_FR.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=fr_FR.UTF-8 LC_IDENTIFICATION=C
#
# time zone: Europe/Paris
# tzcode source: system (glibc)
#
# attached base packages:
# [1] stats4    stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] adverSCarial_1.3.6          IRdisplay_1.1
#  [3] scAnnotatR_1.8.0            SingleCellExperiment_1.23.0
#  [5] SummarizedExperiment_1.31.1 Biobase_2.61.0
#  [7] GenomicRanges_1.53.1        GenomeInfoDb_1.37.2
#  [9] IRanges_2.35.2              S4Vectors_0.39.1
# [11] BiocGenerics_0.47.0         MatrixGenerics_1.13.0
# [13] matrixStats_1.0.0           Seurat_5.1.0
# [15] SeuratObject_5.0.2          sp_2.0-0
#
# loaded via a namespace (and not attached):
#   [1] RcppAnnoy_0.0.20              splines_4.3.0
#   [3] later_1.3.1                   pbdZMQ_0.3-9
#   [5] bitops_1.0-7                  filelock_1.0.2
#   [7] tibble_3.2.1                  polyclip_1.10-4
#   [9] hardhat_1.3.1                 pROC_1.18.5
#  [11] rpart_4.1.19                  fastDummies_1.7.4
#  [13] lifecycle_1.0.3               globals_0.16.2
#  [15] lattice_0.21-8                MASS_7.3-60
#  [17] magrittr_2.0.3                plotly_4.10.2
#  [19] yaml_2.3.7                    httpuv_1.6.11
#  [21] sctransform_0.4.1             spam_2.11-0
#  [23] spatstat.sparse_3.0-2         reticulate_1.36.1
#  [25] cowplot_1.1.1                 pbapply_1.7-2
#  [27] DBI_1.1.3                     RColorBrewer_1.1-3
#  [29] lubridate_1.9.3               abind_1.4-5
#  [31] zlibbioc_1.47.0               Rtsne_0.16
#  [33] purrr_1.0.1                   RCurl_1.98-1.12
#  [35] nnet_7.3-19                   rappdirs_0.3.3
#  [37] ipred_0.9-14                  lava_1.8.0
#  [39] GenomeInfoDbData_1.2.10       data.tree_1.1.0
#  [41] ggrepel_0.9.3                 irlba_2.3.5.1
#  [43] listenv_0.9.0                 spatstat.utils_3.0-3
#  [45] goftest_1.2-3                 RSpectra_0.16-2
#  [47] spatstat.random_3.1-5         fitdistrplus_1.1-11
#  [49] parallelly_1.36.0             leiden_0.4.3
#  [51] codetools_0.2-19              DelayedArray_0.27.5
#  [53] tidyselect_1.2.0              BiocFileCache_2.9.0
#  [55] base64enc_0.1-3               spatstat.explore_3.2-1
#  [57] jsonlite_1.8.5                caret_6.0-94
#  [59] e1071_1.7-14                  ellipsis_0.3.2
#  [61] progressr_0.13.0              iterators_1.0.14
#  [63] ggridges_0.5.4                survival_3.5-5
#  [65] foreach_1.5.2                 tools_4.3.0
#  [67] ica_1.0-3                     Rcpp_1.0.10
#  [69] glue_1.6.2                    prodlim_2023.08.28
#  [71] gridExtra_2.3                 SparseArray_1.1.10
#  [73] dplyr_1.1.2                   withr_2.5.0
#  [75] BiocManager_1.30.21           fastmap_1.1.1
#  [77] fansi_1.0.4                   digest_0.6.32
#  [79] timechange_0.3.0              R6_2.5.1
#  [81] mime_0.12                     colorspace_2.1-0
#  [83] scattermore_1.2               tensor_1.5
#  [85] spatstat.data_3.0-1           RSQLite_2.3.1
#  [87] utf8_1.2.3                    tidyr_1.3.0
#  [89] generics_0.1.3                recipes_1.0.10
#  [91] data.table_1.14.8             class_7.3-22
#  [93] httr_1.4.6                    htmlwidgets_1.6.2
#  [95] S4Arrays_1.1.4                ModelMetrics_1.2.2.2
#  [97] uwot_0.1.15                   pkgconfig_2.0.3
#  [99] gtable_0.3.3                  timeDate_4032.109
# [101] blob_1.2.4                    lmtest_0.9-40
# [103] XVector_0.41.1                htmltools_0.5.5
# [105] dotCall64_1.2                 scales_1.2.1
# [107] png_0.1-8                     gower_1.0.1
# [109] reshape2_1.4.4                uuid_1.1-0
# [111] nlme_3.1-162                  curl_5.0.1
# [113] proxy_0.4-27                  repr_1.1.6
# [115] zoo_1.8-12                    cachem_1.0.8
# [117] stringr_1.5.0                 BiocVersion_3.18.0
# [119] KernSmooth_2.23-21            parallel_4.3.0
# [121] miniUI_0.1.1.1                AnnotationDbi_1.63.1
# [123] pillar_1.9.0                  grid_4.3.0
# [125] vctrs_0.6.3                   RANN_2.6.1
# [127] promises_1.2.0.1              dbplyr_2.3.2
# [129] xtable_1.8-4                  cluster_2.1.4
# [131] evaluate_0.21                 cli_3.6.1
# [133] compiler_4.3.0                rlang_1.1.1
# [135] crayon_1.5.2                  future.apply_1.11.0
# [137] plyr_1.8.8                    stringi_1.7.12
# [139] viridisLite_0.4.2             deldir_1.0-9
# [141] Biostrings_2.69.1             munsell_0.5.0
# [143] lazyeval_0.2.2                spatstat.geom_3.2-1
# [145] Matrix_1.6-4                  IRkernel_1.3.2
# [147] RcppHNSW_0.4.1                patchwork_1.1.2
# [149] bit64_4.0.5                   future_1.32.0
# [151] ggplot2_3.4.2                 KEGGREST_1.41.0
# [153] shiny_1.7.4                   interactiveDisplayBase_1.39.0
# [155] AnnotationHub_3.9.1           kernlab_0.9-32
# [157] ROCR_1.0-11                   igraph_1.5.0
# [159] memoise_2.0.1                 bit_4.0.5
# [161] ape_5.8
